# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# UNIVARIATE FEATURES

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# # READ DATA

# %%
data = pd.read_csv("./train.csv")

# %%
data.head(n=5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X = data.iloc[:,0:20]
y = data.iloc[:,-1]

# %%
print(X.shape,y.shape)
# Out:
# (2000, 20) (2000,)

# %% [markdown]
# # _CHOOSING BEST FEATURES_

# %% [markdown]
# # 1. USING CHI SQUARE

# %%
best_features = SelectKBest(score_func = chi2,k=10)

# %%
fit = best_features.fit(X,y)

# %%
fit.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
scores =pd.DataFrame(fit.scores_)

# %%
scores_col = pd.DataFrame(X.columns)

# %%
scores = pd.concat([scores,scores_col],axis=1)

# %%
scores.columns = ['score','feature']

# %%
scores=scores.sort_values(by='score',ascending=False)

# %%
scores
# Out:
#             score        feature
# 13  931267.519053            ram
# 11   17363.569536      px_height
# 0    14129.866576  battery_power
# 12    9810.586750       px_width
# 8       95.972863      mobile_wt
# 6       89.839124     int_memory
# 15      16.480319           sc_w
# 16      13.236400      talk_time
# 4       10.135166             fc
# 14       9.614878           sc_h
# 10       9.186054             pc
# 9        9.097556        n_cores
# 18       1.928429   touch_screen
# 5        1.521572         four_g
# 7        0.745820          m_dep
# 1        0.723232           blue
# 2        0.648366    clock_speed
# 3        0.631011       dual_sim
# 19       0.422091           wifi
# 17       0.327643        three_g

# %% [markdown]
# #  2.USING IMPORTANT FEATURES(RANDOM FOREST)

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
model = RandomForestClassifier()
model.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
model.feature_importances_
# Out:
# array([0.07486581, 0.00632842, 0.02783474, 0.00609561, 0.02438885,
#        0.0069693 , 0.03812449, 0.02386777, 0.03897191, 0.02302158,
#        0.02867114, 0.05689758, 0.05598634, 0.48222585, 0.02782563,
#        0.02908751, 0.0295158 , 0.00571826, 0.00695895, 0.00664447])

# %%
important_features = pd.DataFrame(model.feature_importances_,index=X.columns)

# %%
important_features.columns = ['Importance']

# %%
important_features
# Out:
#                Importance
# battery_power    0.074866
# blue             0.006328
# clock_speed      0.027835
# dual_sim         0.006096
# fc               0.024389
# four_g           0.006969
# int_memory       0.038124
# m_dep            0.023868
# mobile_wt        0.038972
# n_cores          0.023022
# pc               0.028671
# px_height        0.056898
# px_width         0.055986
# ram              0.482226
# sc_h             0.027826
# sc_w             0.029088
# talk_time        0.029516
# three_g          0.005718
# touch_screen     0.006959
# wifi             0.006644

# %%
important_features = important_features.sort_values(by='Importance',ascending=False)

# %%
important_features
# Out:
#                Importance
# ram              0.482226
# battery_power    0.074866
# px_height        0.056898
# px_width         0.055986
# mobile_wt        0.038972
# int_memory       0.038124
# talk_time        0.029516
# sc_w             0.029088
# pc               0.028671
# clock_speed      0.027835
# sc_h             0.027826
# fc               0.024389
# m_dep            0.023868
# n_cores          0.023022
# four_g           0.006969
# touch_screen     0.006959
# wifi             0.006644
# blue             0.006328
# dual_sim         0.006096
# three_g          0.005718

# %%
plt.style.use("seaborn")
plt.figure(figsize=(20,10))
plt.bar(important_features.index,important_features['Importance'])
plt.show()

# %% [markdown]
# # 3.Correlation method

# %%
import seaborn as sns
corr = data.corr()

# %%
corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# # CHECK THE MODEL PERFORMANCE

# %%
from sklearn.model_selection import cross_val_score

# %%
rfc = RandomForestClassifier()
scores_new = cross_val_score(rfc , X , y ,cv = 10)

# %%
scores_new
# Out:
# array([0.89 , 0.88 , 0.885, 0.885, 0.895, 0.91 , 0.875, 0.85 , 0.855,
#        0.865])

# %%
#this is accuracy
scores_new.mean()
# Out:
# 0.8790000000000001

# %%
#convert previous scores into a numpy array
scores = scores.values

# %%
#take most 10 features
scores = scores[0:10]

# %%
score_compare=[]
for score in scores:
    score_compare.append(score[1])

# %%
X[score_compare]
# Out:
#        ram  px_height  battery_power  px_width  mobile_wt  int_memory  sc_w  \
# 0     2549         20            842       756        188           7     7
# 1     2631        905           1021      1988        136          53     3
# 2     2603       1263            563      1716        145          41     2
# 3     2769       1216            615      1786        131          10     8
# 4     1411       1208           1821      1212        141          44     2
# ...    ...        ...            ...       ...        ...         ...   ...
# 1995   668       1222            794      1890        106           2     4
# 1996  2032        915           1965      1965        187          39    10
# 1997  3057        868           1911      1632        108          36     1
# 1998   869        336           1512       670        145          46    10
# 1999  3919        483            510       754        168          45     4
#
#       talk_time  fc  sc_h
# 0            19   1     9
# ...

# %%
print((cross_val_score(rfc,X[score_compare],y,cv=10)).mean())
#we got accuracy of 90%
# Out:
# 0.9004999999999999
