# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=1000,noise=10,n_features=2,random_state=1,n_informative=2)

# %%
X.shape,y.shape
# Out:
# ((1000, 2), (1000,))

# %% [markdown]
# ### Here first plot is not useful because no linear relation is there
# ### So y = f(x2)

# %%
plt.subplot(1,2,1)
plt.scatter(X[:,0],y)

plt.subplot(1,2,2)
plt.scatter(X[:,1],y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D plot
# - if we want to plot interactive plot in jupyter then use _%matplotlib notebook_

# %%
# %matplotlib notebook
fig = plt.figure()
axes = plt.axes(projection="3d")

axes.scatter3D(X[:,0],X[:,1],y,color="red")
plt.title("3D scatter")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Predictions using sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#theta1 and theta2
model.coef_
# Out:
# array([16.62437639, 87.99042847])

# %%
#theta0 
model.intercept_
# Out:
# -0.21766413760018422

# %%
#predicted vs original y
print(model.predict([X[0]]))
print(y[0])
# Out:
# [-186.58153868]
# -198.36714169030483

# %%
print(model.predict([X[0],X[2]]))
print(y[0],y[2])
# Out:
# [-186.58153868  -76.29172213]
# -198.36714169030483 -86.97032390355662

# %% [markdown]
# # Score

# %%
model.score(X,y)
# Out:
# 0.988401838483157
